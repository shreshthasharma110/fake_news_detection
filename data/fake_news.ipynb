# %%
import pandas as pd
import numpy as np
import matplotlib as plt 
import seaborn as sns

# %%
true = pd.read_csv("True.csv")
fake = pd.read_csv("Fake.csv")

# %%
true.head(5)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head(5)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']= 1
fake['label']= 0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news = pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news.shape
# Out:
# (44898, 5)

# %%
news = news.drop(['title', 'subject', 'date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news.tail()
# Out:
#                                                     text  label
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...      1
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...      1
# 21414  MINSK (Reuters) - In the shadow of disused Sov...      1
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...      1
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...      1

# %% [markdown]
# ## reshuffling

# %%
news = news.sample(frac=1)

# %%
news.head()
# Out:
#                                                     text  label
# 2273   Cards Against Humanity has to be one of the be...      0
# 14561  Has our lawless President finally conceded tha...      0
# 3277   Former President George H. W. Bush can teach D...      0
# 18869  BEIRUT (Reuters) - The Iraqi Kurdish vote for ...      1
# 6713   A customer at a New Orleans Family Dollar stor...      0

# %%
 news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   2273  Cards Against Humanity has to be one of the be...      0
# 1  14561  Has our lawless President finally conceded tha...      0
# 2   3277  Former President George H. W. Bush can teach D...      0
# 3  18869  BEIRUT (Reuters) - The Iraqi Kurdish vote for ...      1
# 4   6713  A customer at a New Orleans Family Dollar stor...      0

# %%
news.drop(['index'],axis= 1, inplace=True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Cards Against Humanity has to be one of the be...      0
# 1  Has our lawless President finally conceded tha...      0
# 2  Former President George H. W. Bush can teach D...      0
# 3  BEIRUT (Reuters) - The Iraqi Kurdish vote for ...      1
# 4  A customer at a New Orleans Family Dollar stor...      0

# %%
import re

# %%
def wordopt(text):
    #Covert into lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+','',text)
    #remove html tags
    text = re.sub(r'<.*?>','',text)
    #Remove punctuation
    text = re.sub(r'[^\w\s]','',text)
    #Remove digits
    text = re.sub(r'\d','',text)
    #remove newline characters
    text = re.sub(r'\n','',text)

    return text

# %%
news['text'] = news ['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        cards against humanity has to be one of the be...
# 1        has our lawless president finally conceded tha...
# 2        former president george h w bush can teach don...
# 3        beirut reuters  the iraqi kurdish vote for ind...
# 4        a customer at a new orleans family dollar stor...
#                                ...
# 44893    luanda reuters  angola s main opposition party...
# 44894    on friday donald trump canceled a rally in chi...
# 44895    washington reuters  youths who were brought to...
# 44896    how many times in one week can abc news publis...
# 44897    the new york daily news is not known for subtl...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        cards against humanity has to be one of the be...
# 1        has our lawless president finally conceded tha...
# 2        former president george h w bush can teach don...
# 3        beirut reuters  the iraqi kurdish vote for ind...
# 4        a customer at a new orleans family dollar stor...
#                                ...
# 44893    luanda reuters  angola s main opposition party...
# 44894    on friday donald trump canceled a rally in chi...
# 44895    washington reuters  youths who were brought to...
# 44896    how many times in one week can abc news publis...
# 44897    the new york daily news is not known for subtl...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 44893    1
# 44894    0
# 44895    1
# 44896    0
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %% [markdown]
# ## feature extraction

# %%
from sklearn.feature_extraction.text import
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 from sklearn.feature_extraction.text import TfidVectorizer
#
# ImportError: cannot import name 'TfidVectorizer' from 'sklearn.feature_extraction.text' (C:\ProgramData\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py)
